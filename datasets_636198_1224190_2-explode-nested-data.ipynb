# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import gc

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/stanford-plato-corpus/1-make-data-csv.ipynb
# /kaggle/input/stanford-plato-corpus/data.csv
# /kaggle/input/stanford-plato-corpus/simple_data.csv
# /kaggle/input/stanford-plato-corpus/corpus_article_text_features.csv
# /kaggle/input/stanford-plato-corpus/data_per_paragraph.csv
# /kaggle/input/stanford-plato-corpus/corpus_articles.csv
# /kaggle/input/stanford-plato-corpus/explode-nested-data.ipynb
# /kaggle/input/stanford-plato-corpus/plato_mirror_spr2020.tgz
# /kaggle/input/stanford-plato-corpus/make-final-plato-corpus.ipynb

# %%
CSV_FILE = "/kaggle/input/stanford-plato-corpus/simple_data.csv"

# %%
df = pd.read_csv(CSV_FILE)

# %%
df.size
# Out:
# 46500

# %%
df.shape
# Out:
# (4650, 10)

# %%
df.head()
# Out:
#                                            filenames filetype  \
# 0  stanford.library.sydney.edu.au/entries/medieva...    .html
# 1  stanford.library.sydney.edu.au/entries/moral-a...    .html
# 2  stanford.library.sydney.edu.au/entries/moral-a...    .html
# 3  stanford.library.sydney.edu.au/entries/music/i...    .html
# 4  stanford.library.sydney.edu.au/entries/identit...    .html
#
#                  topic                                title            author  \
# 0  medieval-categories  Medieval Theories of the Categories     Gracia, Jorge
# 1         moral-animal                                  NaN               NaN
# 2         moral-animal          The Moral Status of Animals       Gruen, Lori
# 3                music              The Philosophy of Music     Kania, Andrew
# 4  identity-transworld                  Transworld Identity  Mackie, Penelope
#
#             creator                                      preamble_text  \
# 0     Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
# 1               NaN                                                NaN
# 2       Gruen, Lori  \n\nIs there something distinctive about human...
# 3     Kania, Andrew  \n\nPhilosophy of music is the study of fundam...
# 4  Mackie, Penelope  \n\nThe notion of transworld identity—‘identit...
#
#                                             sections  \
# 0  [{'id': 1, 'heading_text': '1. Issues', 'parag...
# 1                                                NaN
# 2  [{'id': 1, 'heading_text': '1. The Moral Consi...
# 3  [{'id': 1, 'heading_text': '1. What Is Music?'...
# 4  [{'id': 1, 'heading_text': '1. What is transwo...
#
#                                 related_entries_list  \
# 0  ['../analogy-medieval/', '../binarium/', '../c...
# 1                                                NaN
# 2  ['../bentham/', '../consciousness-animal/', '....
# 3  ['../aesthetic-judgment/', '../al-farabi/', '....
# 4  ['../actualism/', '../essential-accidental/', ...
#
#                                           plain_text
# 0  \n\n\n\n\n  \n\n\n\nMedieval Theories of the C...
# 1  \n\n\n\n\n  \n\n\n\nThe Moral Status of Animal...
# 2  \n\n\n\n\n  \n\n\n\nThe Moral Status of Animal...
# 3  \n\n\n\n\n  \n\n\n\nThe Philosophy of Music (S...
# 4  \n\n\n\n\n  \n\n\n\nTransworld Identity (Stanf...

# %%
df['filenames'][2]
# Out:
# 'stanford.library.sydney.edu.au/entries/moral-animal/index.html'

# %%
df['sections'][2]
# Out:
# "[{'id': 1, 'heading_text': '1. The Moral Considerability of Animals', 'paragraphs': [{'id': 1, 'text': '\\nTo say that a being deserves moral consideration is to say that there\\nis a moral claim that this being can make on those who can recognize\\nsuch claims. A morally considerable being is a being who can be\\nwronged. It is often thought that because only humans can recognize\\nmoral claims, it is only humans who are morally considerable. However,\\nwhen we ask why we think humans are the only types of beings that can\\nbe morally wronged, we begin to see that the class of beings able to\\nrecognize moral claims and the class of beings who can suffer moral\\nwrongs are not co-extensive.'}]}, {'id': 2, 'heading_text': '1.1 Speciesism', 'paragraphs': [{'id': 1, 'text': '\\nThe view that only humans are morally considered is sometimes referred\\nto as “speciesism”. In the 1970s, Richard Ryder coined\\nthis term while campaigning in Oxford to denote a ubiquitous type of human centered prejudice, which he\\nthought was similar to racism. He objected to favoring one’s own\\nspecies, while exploiting or harming members of other species. Peter\\nSinger popularized the term and focused on the way speciesism, without\\nmoral justification, favors the interests of humans: '}, {'id': 2, 'text': '\\nthe racist violates the principle of equality by giving greater weight\\nto the interests of members of his own race, when there is a clash\\nbetween their interests and the interests of those of another race.\\nSimilarly the speciesist allows the interests of his own species to\\noverride the greater interests of members of other species. The\\npattern is the same in each case. (Singer 1974: 108) '}, {'id': 3, 'text': '\\nDiscrimination based on race, like discrimination based on species is\\nthought to be prejudicial, because these are not characteristics that\\nmatter when it comes to making moral claims.'}, {'id': 4, 'text': '\\nSpeciesist actions and attitudes are prejudicial because there is no\\nprima facie reason for preferring the interests of beings\\nbelonging to the species group to which one also belongs over the\\ninterests of those who don’t. That humans are members of the\\nspecies Homo sapiens is certainly a distinguishing feature of\\nhumans—humans share a genetic make-up and a distinctive\\nphysiology, we all emerge from a human pregnancy, but this is\\nunimportant from the moral point of view. Species membership is a\\nmorally irrelevant characteristic, a bit of luck that is no more\\nmorally interesting than being born in Malaysia or Canada. As a\\nmorally irrelevant characteristic it cannot serve as the basis for a\\nview that holds that our species deserves moral consideration that is\\nnot owed to members of other species.'}, {'id': 5, 'text': '\\nOne might respond that it is not membership in a biological category\\nthat matters morally, but rather the social meaning of those\\ncategories, meanings that structure not only the institutions we\\noperate within, but how we conceptualize ourselves and our world.\\nHumans have developed moral systems as well as a wide range of other\\nvaluable practices, and by creating these systems, we separate the\\nhuman from the rest of the animal kingdom. But the category\\n“human” itself is morally contested. Some argue, for\\nexample, that racism is not simply, or even primarily about\\ndiscrimination and prejudice, but rather a mechanism of dehumanizing\\nblackness so as to provide the conditions that makes humans white (see\\nFanon 1967; Kim 2015; Ko& Ko 2017). According\\nto this line of thought, speciesism isn’t focused on\\ndiscrimination or prejudice but is a central tool for creating human\\n(and white) supremacy or exceptionalism.'}]}, {'id': 3, 'heading_text': '1.2 Human Exceptionalism', 'paragraphs': [{'id': 1, 'text': '\\nLike speciesism, human exceptionalism can be understood in different\\nways. The most common way of understanding it is to suggest that there\\nare ...

# %%
df.columns
# Out:
# Index(['filenames', 'filetype', 'topic', 'title', 'author', 'creator',
#        'preamble_text', 'sections', 'related_entries_list', 'plain_text'],
#       dtype='object')

# %%
def string_to_python_list(x):
    return eval(x) if isinstance(x,str) else None

df['related_entries_list'] = df['related_entries_list'].apply(string_to_python_list)

# %%
df['sections'] = df['sections'].apply(string_to_python_list)

# %%
df['sections'][1]

# %% [markdown]
# # Now explode

# %% [markdown]
# ### [example](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.explode.html)

# %%
example_df = pd.DataFrame({'A': [[1, 2, 3], 'foo', [], [3, 4]], 'B': 1})
example_df
# Out:
#            A  B
# 0  [1, 2, 3]  1
# 1        foo  1
# 2         []  1
# 3     [3, 4]  1

# %%
example_df.explode("A")
# Out:
#      A  B
# 0    1  1
# 0    2  1
# 0    3  1
# 1  foo  1
# 2  NaN  1
# 3    3  1
# 3    4  1

# %% [markdown]
# # ~~Explode ***related_entries_list***~~
# ## bad idea... too many rows

# %%
# related_topic_per_row_df = df.explode("related_entries_list")

# %%
# related_topic_per_row_df.head()

# %%
# section_per_row_and_related_topic_per_row_df = related_topic_per_row_df.explode("sections")

# %%
# section_per_row_and_related_topic_per_row_df.head()

# %% [markdown]
# # Just explode the sections
# ## to later extract paragraphs

# %%
df = df.explode("sections")

# %%
df.columns
# Out:
# Index(['filenames', 'filetype', 'topic', 'title', 'author', 'creator',
#        'preamble_text', 'sections', 'related_entries_list', 'plain_text'],
#       dtype='object')

# %%
# df = df.rename(columns={"related_entries_list": "related_topic"})
df = df.rename(columns={"sections": "section"})
df = df.rename(columns={"filenames": "filename"})

# %%
df.head()
# Out:
#                                             filename filetype  \
# 0  stanford.library.sydney.edu.au/entries/medieva...    .html
# 0  stanford.library.sydney.edu.au/entries/medieva...    .html
# 0  stanford.library.sydney.edu.au/entries/medieva...    .html
# 0  stanford.library.sydney.edu.au/entries/medieva...    .html
# 0  stanford.library.sydney.edu.au/entries/medieva...    .html
#
#                  topic                                title         author  \
# 0  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
# 0  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
# 0  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
# 0  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
# 0  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
#
#          creator                                      preamble_text  \
# 0  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
# 0  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
# 0  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
# 0  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
# 0  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
#
#                                              section  \
# 0  {'id': 1, 'heading_text': '1. Issues', 'paragr...
# 0  {'id': 2, 'heading_text': '2. Classical Backgr...
# 0  {'id': 3, 'heading_text': '3. Early Middle Age...
# 0  {'id': 4, 'heading_text': '4. Thirteenth Centu...
# 0  {'id': 5, 'heading_text': '4.1 Robert Kilwardb...
#
#                                 related_entries_list  \
# 0  [../analogy-medieval/, ../binarium/, ../catego...
# 0  [../analogy-medieval/, ../binarium/, ../catego...
# 0  [../analogy-medieval/, ../binarium/, ../catego...
# 0  [../analogy-medieval/, ../binarium/, ../catego...
# 0  [../analogy-medieval/, ../binarium/, ../catego...
#
#                                           plain_text
# 0  \n\n\n\n\n  \n\n\n\nMedieval Theories of the C...
# 0  \n\n\n\n\n  \n\n\n\nMedieval Theories of the C...
# 0  \n\n\n\n\n  \n\n\n\nMedieval Theories of the C...
# 0  \n\n\n\n\n  \n\n\n\nMedieval Theories of the C...
# 0  \n\n\n\n\n  \n\n\n\nMedieval Theories of the C...

# %% [markdown]
# # Now extract all the section.id & section.heading_text & section.paragraphs on the section JSON

# %% [markdown]
# ### first notice the keys

# %%
df['section'].values[1]
# Out:
# {'id': 2,
#  'heading_text': '2. Classical Background (pre–500 C.E.)',
#  'paragraphs': [{'id': 1,
#    'text': '\n\nThe philosophical discussion of categories begins with Aristotle\n(B.C.E. 384–322). His view is difficult to interpret, even though\nthe texts dealing with this topic (Categories, Topics\nI, and Metaphysics V) are characteristically direct\nin style. Still, there is some consensus among scholars that Aristotle\nproposes three ways of understanding categories: as realities,\nconcepts, and linguistic terms. Much of the subsequent philosophical\ndiscussion of categories concerns the correctness of this view. Some\nfavor a position according to which categories are realities, which\nare then said to be reflected in thought and language; some endorse a\nview of them merely as concepts, which are also said to be reflected\nin language; some maintain that categories are merely linguistic\nterms, and reject any implication that they are real entities or\nconcepts; and still others maintain an inclusive view that contends\nthat categories are all three: words, concepts, and extra-mental\nentities.'},
#   {'id': 2,
#    'text': "\n\nThe Greek term that Aristotle uses for category means predicate\n(categoria) so that categories would appear to be\nkinds of predicates, the most general kinds of predicates. However,\nsome commentators claim that Aristotle uses the term rather for kinds\nof predication and kinds of beings (for example in Topics\n103b20–27, and Metaphysics 1017a22–27; see Frede\n1987, 29–48). In Categories, Aristotle uses the term\ntechnically to refer to substance, quantity,\nquality, relation, place, time,\nposition, state, action, and\naffection (9a27, 11b37, 11b7), although he also speaks of\nless general terms, such as ‘white,’ ‘half,’\nand ‘last year,’ and trans-categorial terms such as\n‘good’ and ‘unity.’ Aristotle's\ncategories are not, strictly speaking, the predicates we use when we\nspeak in ordinary language; rather, they are the most general kinds of\npredicates, or predications. Thus ‘white’ and\n‘here’ do not refer to categories, but\n‘quality’ and ‘place’ do. The Aristotelian\ncategories may be taken as the most general predicates which can be\npredicated or, alternatively, they are the most general kinds of\npredication into which the predicates we use in ordinary discourse may\nbe classified. They provide answers to direct questions such as when,\nwhere, how, what, and so on. Terms that extend to more than one\ncategory (e.g., ‘good’), or do not apply to categories\n(e.g., ‘and’) are treated separately."},
#   {'id': 3,
#    'text': '\n\nPredicability, then, is not a sufficient condition of categoricity,\nbut non-predicability is a sufficient disqualification. For Aristotle,\nthe individual is not, strictly speaking, predicable, although there\nare places in which he speaks of the individual as\npredicable. Examples of individuals are this horse and a\ncertain point of grammar present in the knower (1b5). The first\nis what Aristotle calls a primary substance, which he defines\nin Categories as that which is neither predicable of, nor\npresent in, a subject (2a11). The second is, like a primary substance,\nnon-predicable, but it can be present in a subject. Both are\nindividual and neither is predicable.'},
#   {'id': 4,
#    'text': "\n\nThat Aristotle refers to categories with the Greek term which\ncorresponds roughly to the term ‘predicate’ in English\ndoes not mean that he understood categories to be merely linguistic\nterms.  Indeed, ‘predicate’ itself is used in a variety of\nways by philosophers. Some think of predicates as properties of some\nkind, some as concepts, some as words, and so on. Therefore, to say\nthat something is a predicate does not necessarily mean that it is a\nlinguistic term.  In the case of Aristotle, there is ample evidence in\nCategories itself which suggests that categories are not just\nlinguistic terms that reflect the fundamental ways in which we speak\nabout things, but also ways in which things are. The interpretative\ntradition that favors a linguistic or logical understanding of the\ncategories goes back at least to Porphyry (1887, 56), who tries to\nreconcile what he takes to be Aristotle's linguistic/logical position\nwith Plato's metaphysics (Ebbesen 1990). Consider for example how\nAristotle introduces the categories: “Of things said without any\ncombination, each signifies either a substance or quantity or\nqualification or a relative or where or when or being-in-a-position or\nhaving or doing or being-affected” (1b25). Clearly, he is\ntalking about language when he says, “Of things said\nwithout combination, each signifies….” for\nthings that are said and that signify are linguistic terms\n(Poetics 1456b38ff; our emphasis). The linguistic emphasis is\nreinforced elsewhere, when he adds that “of things which are\nsaid without any combination none is either true or\nfalse…” (2a9)."},
#   {'id': 5,
#    'text': '\n\nAt the same time, these statements do not imply that what is signified\nnecessarily has to be linguistic. Indeed, earlier in\nCategories, Aristotle unabashedly mixes the language of\n“language” with the language of “being” when\nhe notes: “Of things that are: some are said\nof a subject but are not in any subject. For example, man is\nsaid of a subject, the individual man, but is not in any\nsubject” (1a20; our emphasis). This text begins with a reference\nto things that are (ta onta), but goes on to speak about\nthings that are said (ta legomena). The same occurs in other\nplaces (2a11). In a text from Metaphysics (1017a23–25),\nthe isomorphism between being and language is openly expressed.'},
#   {'id': 6,
#    'text': '\n\nAristotle is less explicit about the understanding of categories as\nconcepts. In Categories generally he does not speak about how\nthings are conceived; rather, he speaks about how things are\ncalled or how they are. At the same time, from what\nhe says elsewhere about signification and the way we think, it is not\nunreasonable to surmise that he also thinks of categories as concepts\nof some kind. For example, at the beginning of On\nInterpretation, he claims that “spoken sounds are symbols\nof affections [or concepts] in the soul, and written marks symbols of\nspoken sounds. And just as written marks are not the same for all men,\nneither are spoken sounds. But what these are in the first place\nsounds of–affections of the soul–are the same for all; and\nwhat these affections are likenesses of–actual things–are\nalso the same” (16a 4–8).'},
#   {'id': 7,
#    'text': '\n\nNone of this, however, is very clear. Indeed, Aristotle never actually\nsays that categories are words, concepts, or realities; he only speaks\nof them as categories, that is, predicates. But\n‘predicate’ can be used to mean realities, concepts, or\nlinguistic terms. Aristotle does speak of categories as if\nthey were realities or linguistic terms, and one can further infer\nthat he could have spoken of them as if they were\nconcepts. But this does not definitely clarify what he thinks about\nthem. Indeed, on the basis of what he says we cannot determine for\nsure that he even raises the question of the ultimate ontological\nstatus of categories.  The situation is further obscured because\nAristotle never identifies the discipline where categories are\nsupposed to be studied and he treats them in both logical\n(Categories, Topics) and metaphysical\n(Metaphysics) contexts.'},
#   {'id': 8,
#    'text': '\n\nOne more point needs to be made clear. Aristotle never clearly and\nconsistently ties the categories to sentential or propositional\nstructure. In Categories he appears to consider them in\nisolation from their syntactical context, but in Topics\n(103b20–27) and Metaphysics (1017a23–25) he seems\nto tie them to predication and, thus, to consider them in relation to\na syntactical context. This ambiguity gives rise to different\ninterpretations, such as that of Frede, who considers them to be kinds\nof predications (1987), and that of Ryle, who views them as\nindependent from syntactical context (1971). In short, the picture is\nfar from clear, and this serves to separate Aristotle from authors who\nexplicitly and exclusively view categories as reflecting syntactical\ncontexts.'},
#   {'id': 9,
#    'text': '\n\nThe same ambiguity with respect to the ontological status of\ncategories that we find in Aristotle is found in many of his medieval\ncommentators. Perhaps this can be taken as a sign that they believe\ncategories to be realities, concepts, and linguistic terms, that is,\nthat categories are ways in which the world is, ways in which we think\nabout the world, and ways in which we speak about the world. However,\nthere are some who argue for purely linguistic or conceptual ways of\nunderstanding categories. In modern philosophy, the emphasis shifts\ntoward the language of thought, a prime example of which is Immanuel\nKant (1724–1804; see Gracia 2000).'}]}

# %%
df['section'].values[2].keys()
# Out:
# dict_keys(['id', 'heading_text', 'paragraphs'])

# %%
df['section'].values[2]['paragraphs'][0].keys()
# Out:
# dict_keys(['id', 'text'])

# %% [markdown]
# ## Now safely get the dictionary values

# %%
def safe_get(getter=lambda x, n: x):
    def _get(x):
        if x == None:
            return None
        elif isinstance(x, dict):
            return getter(x)
        else:
            raise NotImplementedError()
    return _get

def _id_getter(x):
    return x["id"]

def _ht_getter(x):
    return x["heading_text"]

def _p_getter(x):
    return x["paragraphs"]

def _text_getter(x):
    return x["text"]

# %%
df['section.id'] = df['section'].apply(safe_get(_id_getter))
df['section.heading_text'] = df['section'].apply(safe_get(_ht_getter))
df['section.paragraphs'] = df['section'].apply(safe_get(_p_getter))

# %% [markdown]
# # Explode the section.paragraphs which is also list-of-dict

# %%
df = df.explode("section.paragraphs")

# %% [markdown]
# a better name

# %%
df = df.rename(columns={"section.paragraphs": "section.paragraph"})

# %% [markdown]
# # Now extract the *section.paragraph.id* and *section.paragraph.text*

# %%
df['section.paragraph.id'] = df['section.paragraph'].apply(safe_get(_id_getter))
df['section.paragraph.text'] = df['section.paragraph'].apply(safe_get(_text_getter))

# %%
df.head()
# Out:
#                                             filename filetype  \
# 0  stanford.library.sydney.edu.au/entries/medieva...    .html
# 0  stanford.library.sydney.edu.au/entries/medieva...    .html
# 0  stanford.library.sydney.edu.au/entries/medieva...    .html
# 0  stanford.library.sydney.edu.au/entries/medieva...    .html
# 0  stanford.library.sydney.edu.au/entries/medieva...    .html
#
#                  topic                                title         author  \
# 0  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
# 0  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
# 0  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
# 0  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
# 0  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
#
#          creator                                      preamble_text  \
# 0  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
# 0  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
# 0  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
# 0  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
# 0  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
#
#                                              section  \
# 0  {'id': 1, 'heading_text': '1. Issues', 'paragr...
# 0  {'id': 1, 'heading_text': '1. Issues', 'paragr...
# 0  {'id': 1, 'heading_text': '1. Issues', 'paragr...
# 0  {'id': 1, 'heading_text': '1. Issues', 'paragr...
# 0  {'id': 1, 'heading_text': '1. Issues', 'paragr...
#
#                                 related_entries_list  \
# 0  [../analogy-medieval/, ../binarium/, ../catego...
# 0  [../analogy-medieval/, ../binarium/, ../catego...
# 0  [../analogy-medieval/, ../binarium/, ../catego...
# 0  [../analogy-medieval/, ../binarium/, ../catego...
# 0  [../analogy-medieval/, ../binarium/, ../catego...
#
#                                           plain_text  section.id  \
# 0  \n\n\n\n\n  \n\n\n\nMedieval Theories of the C...         1.0
# 0  \n\n\n\n\n  \n\n\n\nMedieval Theories of the C...         1.0
# 0  \n\n\n\n\n  \n\n\n\nMedieval Theories of the C...         1.0
# 0  \n\n\n\n\n  \n\n\n\nMedieval Theories of the C...         1.0
# 0  \n\n\n\n\n  \n\n\n\nMedieval Theories of the C...         1.0
#
#   section.heading_text                                  section.paragraph  \
# 0            1. Issues  {'id': 1, 'text': '
#
# Philosophers speak about ...
# 0            1. Issues  {'id': 2, 'text': '
#
# The disagreement concerni...
# 0            1. Issues  {'id': 3, 'text': '
#
# The first group comprises...
# 0            1. Issues  {'id': 4, 'text': '
#
# The second group is rough...
# 0            1. Issues  {'id': 5, 'text': '
#
# The third group is ontolo...
#
#    section.paragraph.id                             section.paragraph.text
# 0                   1.0  \n\nPhilosophers speak about categories in man...
# 0                   2.0  \n\nThe disagreement concerning categories in ...
# 0                   3.0  \n\nThe first group comprises what may be desc...
# 0                   4.0  \n\nThe second group is roughly intensional; t...
# 0                   5.0  \n\nThe third group is ontological; the issues...

# %% [markdown]
# # Now just choose the useful columns to conserve memory
#
# ### consider that the `section` dict is no longer needed since the data was extracted. same for `section.paragraph`
#
# ### also consider that `plain_text` duplicates the `section.paragraph.text` without the granualar section/paragraph structure

# %%
df.columns
# Out:
# Index(['filename', 'filetype', 'topic', 'title', 'author', 'creator',
#        'preamble_text', 'section', 'related_entries_list', 'plain_text',
#        'section.id', 'section.heading_text', 'section.paragraph',
#        'section.paragraph.id', 'section.paragraph.text'],
#       dtype='object')

# %%
mask = [
    'filename', 'filetype', 'topic', 'title', 'author', 'creator',
    'preamble_text', 
    #'section', 
    'related_entries_list', 
    # 'plain_text',
    'section.id', 'section.heading_text', 
    # 'section.paragraph', 
    'section.paragraph.id', 'section.paragraph.text'
]
df = df[mask]

# %%
df.size
# Out:
# 1879464

# %%
df.shape
# Out:
# (156622, 12)

# %%
len(df)
# Out:
# 156622

# %%
df.head()
# Out:
#                                             filename filetype  \
# 0  stanford.library.sydney.edu.au/entries/medieva...    .html
# 0  stanford.library.sydney.edu.au/entries/medieva...    .html
# 0  stanford.library.sydney.edu.au/entries/medieva...    .html
# 0  stanford.library.sydney.edu.au/entries/medieva...    .html
# 0  stanford.library.sydney.edu.au/entries/medieva...    .html
#
#                  topic                                title         author  \
# 0  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
# 0  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
# 0  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
# 0  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
# 0  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
#
#          creator                                      preamble_text  \
# 0  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
# 0  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
# 0  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
# 0  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
# 0  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
#
#                                 related_entries_list  section.id  \
# 0  [../analogy-medieval/, ../binarium/, ../catego...         1.0
# 0  [../analogy-medieval/, ../binarium/, ../catego...         1.0
# 0  [../analogy-medieval/, ../binarium/, ../catego...         1.0
# 0  [../analogy-medieval/, ../binarium/, ../catego...         1.0
# 0  [../analogy-medieval/, ../binarium/, ../catego...         1.0
#
#   section.heading_text  section.paragraph.id  \
# 0            1. Issues                   1.0
# 0            1. Issues                   2.0
# 0            1. Issues                   3.0
# 0            1. Issues                   4.0
# 0            1. Issues                   5.0
#
#                               section.paragraph.text
# 0  \n\nPhilosophers speak about categories in man...
# 0  \n\nThe disagreement concerning categories in ...
# 0  \n\nThe first group comprises what may be desc...
# 0  \n\nThe second group is roughly intensional; t...
# 0  \n\nThe third group is ontological; the issues...

# %% [markdown]
# # more tricks to conserve memory

# %%
def chunks(lst, N):
    """Yield N successive `len(lst)//N`-sized chunks from lst."""
    chunk_size = len(lst)//N
    for i in range(0, len(lst), len(lst)//N):
        yield lst[i:i + chunk_size]

# %%
TOTAL_CHUNKS = 10000

# %%
df_generator = chunks(df, TOTAL_CHUNKS)

# %% [markdown]
# # Now save

# %%
CSV_FILENAME = "data_per_paragraph.csv"

# save first one
first_with_header = next(df_generator)

first_with_header.to_csv(CSV_FILENAME, mode='w', header=True)

# %%
del first_with_header
gc.collect()
# Out:
# 20

# %%
i = 2
COLLECTED = gc.collect()
print(COLLECTED)
for x in df_generator:
#     if (i % 1000 == 0):
#         COLLECTED = gc.collect()
    print(f"appending... {i} / {TOTAL_CHUNKS}\r", end="")
    x.to_csv(CSV_FILENAME, mode='a', header=False)
    i+=1
# Out:
# 20
# appending... 10442 / 10000

# %% [markdown]
# # read the output to make sure all is well

# %%
pd.read_csv(CSV_FILENAME).head()
# Out:
#    Unnamed: 0                                           filename filetype  \
# 0           0  stanford.library.sydney.edu.au/entries/medieva...    .html
# 1           0  stanford.library.sydney.edu.au/entries/medieva...    .html
# 2           0  stanford.library.sydney.edu.au/entries/medieva...    .html
# 3           0  stanford.library.sydney.edu.au/entries/medieva...    .html
# 4           0  stanford.library.sydney.edu.au/entries/medieva...    .html
#
#                  topic                                title         author  \
# 0  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
# 1  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
# 2  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
# 3  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
# 4  medieval-categories  Medieval Theories of the Categories  Gracia, Jorge
#
#          creator                                      preamble_text  \
# 0  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
# 1  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
# 2  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
# 3  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
# 4  Gracia, Jorge  \n\n\nThis entry is intended as a brief and ge...
#
#                                 related_entries_list  section.id  \
# 0  ['../analogy-medieval/', '../binarium/', '../c...         1.0
# 1  ['../analogy-medieval/', '../binarium/', '../c...         1.0
# 2  ['../analogy-medieval/', '../binarium/', '../c...         1.0
# 3  ['../analogy-medieval/', '../binarium/', '../c...         1.0
# 4  ['../analogy-medieval/', '../binarium/', '../c...         1.0
#
#   section.heading_text  section.paragraph.id  \
# 0            1. Issues                   1.0
# 1            1. Issues                   2.0
# 2            1. Issues                   3.0
# 3            1. Issues                   4.0
# 4            1. Issues                   5.0
#
#                               section.paragraph.text
# 0  \n\nPhilosophers speak about categories in man...
# 1  \n\nThe disagreement concerning categories in ...
# 2  \n\nThe first group comprises what may be desc...
# 3  \n\nThe second group is roughly intensional; t...
# 4  \n\nThe third group is ontological; the issues...

# %% [markdown]
# # What's up with the np.nan paragraphs?
#
# It seems those paragraphs (if any) did not fit the HTML stucture assumptions when the data was extracted from the web archive.
#
# That's okay.
#
# TODO: consider dealing with these files counted below...

# %%
df[df["section.paragraph.text"].isna()].groupby("filetype").count()
# Out:
#           filename  topic  title  author  creator  preamble_text  \
# filetype
# .au              2      2      0       0        0              0
# .doc             1      1      0       0        0              0
# .docx            1      1      0       0        0              0
# .gif           210    210      0       0        0              0
# .html         2399   2399   1294    1294     1294           1294
# .jpeg            3      3      0       0        0              0
# .jpg           458    458      0       0        0              0
# .js            312    312      0       0        0              0
# .png           690    690      0       0        0              0
# .qt              2      2      0       0        0              0
# .svg           176    176      0       0        0              0
# .tex             1      1      0       0        0              0
# .tgz             1      1      0       0        0              0
# .wav             2      2      0       0        0              0
#
#           related_entries_list  section.id  section.heading_text  \
# filetype
# .au                          0           0                     0
# .doc                         0           0                     0
# .docx                        0           0                     0
# .gif                         0           0                     0
# .html                     1294        1294                  1294
# .jpeg                        0           0                     0
# .jpg                         0           0                     0
# .js                          0           0                     0
# .png                         0           0                     0
# .qt                          0           0                     0
# .svg                         0           0                     0
# .tex                         0           0                     0
# .tgz                         0           0                     0
# .wav                         0           0                     0
#
#           section.paragraph.id  section.paragraph.text
# filetype
# .au                          0                       0
# .doc                         0                       0
# .docx                        0                       0
# .gif                         0                       0
# .html                        0                       0
# .jpeg                        0                       0
# .jpg                         0                       0
# .js                          0                       0
# .png                         0                       0
# .qt                          0                       0
# .svg                         0                       0
# .tex                         0                       0
# .tgz                         0                       0
# .wav                         0                       0

# %%
na_par_df = df[df["section.paragraph.text"].isna()]
(
    na_par_df.join(
        na_par_df["filename"].apply(lambda x: os.path.split(x)[1]),
        rsuffix="_____"
    ).groupby("filename_____")
    .count()
    .sort_values(["filename","filetype","topic","title","author"], ascending=False)
)
# Out:
#                            filename  filetype  topic  title  author  creator  \
# filename_____
# index.html                     3768      3768   3768   3768    3768     3768
# notes.html                      617       617    617      0       0        0
# local.js                        312       312    312      0       0        0
# supplement.html                  46        46     46      0       0        0
# fig1.png                         25        25     25      0       0        0
# ...                             ...       ...    ...    ...     ...      ...
# wilson-cell.jpg                   1         1      1      0       0        0
# wimsatt-maxima-levels.png         1         1      1      0       0        0
# word-meaning-tree.png             1         1      1      0       0        0
# young-meinong.jpg                 1         1      1      0       0        0
# zombie.png                        1         1      1      0       0        0
#
#                            preamble_text  related_entries_list  section.id  \
# filename_____
# index.html                          3768                  3768        3768
# notes.html                             0                     0           0
# local.js                               0                     0           0
# supplement.html                        0                     0           0
# fig1.png                               0                     0           0
# ...                                  ...                   ...         ...
# wilson-cell.jpg                        0                     0           0
# wimsatt-maxima-levels.png              0                     0           0
# word-meaning-tree.png                  0                     0           0
# young-meinong.jpg                      0                     0           0
# zombie.png                             0                     0           0
#
#                            section.heading_text  section.paragraph.id  \
# filename_____
# index.html                                 3768                     0
# notes.html                                    0                     0
# local.js                                      0                     0
# supplement.html                               0                     0
# fig1.png                                      0                     0
# ...                                         ...                   ...
# wilson-cell.jpg                               0                     0
# wimsatt-maxima-levels.png                     0                     0
# word-meaning-tree.png                         0                     0
# young-meinong.jpg                             0                     0
# zombie.png                                    0                     0
#
#                            section.paragraph.text
# filename_____
# index.html                                      0
# notes.html                                      0
# local.js                                        0
# supplement.html                                 0
# fig1.png                                        0
# ...                                           ...
# wilson-cell.jpg                                 0
# wimsatt-maxima-levels.png                       0
# word-meaning-tree.png                           0
# young-meinong.jpg                               0
# zombie.png                                      0
#
# [1597 rows x 12 columns]
